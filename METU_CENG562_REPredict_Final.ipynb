# %% [markdown]
# # Ames House Price Prediction

# %%
### Imports ###
import os
import shutil

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from datetime import datetime
from pathlib import Path
from typing import Any, Dict, Iterable

from google.colab import files
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.neural_network import MLPRegressor

# %% [markdown]
# ## 2. Dataset

# %% [markdown]
# ### 2.1. Importing the Dataset

# %%
### Upload and set Kaggle API Token ###
# Prerequisite: Have your API token file in your local computer
# Edit this path if it does not match the name of your file
token_upload_path: Path = "./kaggle.json"
token_expected_dir: Path = "/root/.kaggle"

# Upload
if os.path.exists(token_upload_path):
  print(
      f"Skipping Kaggle API token upload, there is already something at: "
      f"{token_upload_path}"
  )
else:
  print("Please upload your Kaggle API token file.")
  files.upload()

# Move to expected dir
token_expected_path: Path = f"{token_expected_dir}/kaggle.json"
if os.path.isfile(token_expected_path):
  print(
      f"Skipping Kaggle API token move, there is already something at: "
      f"{token_expected_path}"    
  )
else:
  print(f"Moving Kaggle API token file to: {token_expected_path}")
  try:
    os.mkdir(token_expected_dir)
  except FileExistsError:
    pass  # Directory already exists
  except FileNotFoundError as e:
    print("Could not create Kaggle API token directory.")
    raise e
  shutil.copy(token_upload_path, token_expected_path)
# Out:
# Please upload your Kaggle API token file.
#      <input type="file" id="files-51a546a0-43d0-42c9-956d-71a83671afde" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-51a546a0-43d0-42c9-956d-71a83671afde">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...

# %%
### Import Dataset ###
# !kaggle competitions download -c house-prices-advanced-regression-techniques
# !mkdir -p ./dataset
# !unzip house-prices-advanced-regression-techniques.zip -d ./dataset
# Out:
# ...
#   0% 0.00/199k [00:00<?, ?B/s]
# 100% 199k/199k [00:00<00:00, 92.4MB/s]
# Archive:  house-prices-advanced-regression-techniques.zip
#   inflating: ./dataset/data_description.txt
#   inflating: ./dataset/sample_submission.csv
#   inflating: ./dataset/test.csv
#   inflating: ./dataset/train.csv

# %%
### Read Data Into DataFrame ###
df: pd.DataFrame = pd.read_csv("./dataset/train.csv")

# %% [markdown]
# ### 2.2. Visualization and Analysis

# %%
### Visualize Raw Data ###
df.info()
df.describe().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
### Show Price Plot ###
df.plot.scatter("Id", "SalePrice")

# %%
### Show Correlation Map ###
corr_df = df.corr()
fig, ax = plt.subplots(figsize=(30, 30))
sns.heatmap(corr_df, annot=True, ax=ax, linewidth=0.5, fmt=".2f")
plt.show()

# %%
def list_non_numerical_vars(input: pd.DataFrame) -> Dict[str, Iterable[Any]]:
  """
  Finds non-numerical variables from the input and returns them in a key to
  unique values mapping.
  """
  obj_columns : Iterable[str] = list(input.select_dtypes(include=["object"]).columns)
  ret: Dict[str, Iterable[Any]] = {}
  for col in obj_columns:
    ret[col] = input[col].unique().tolist()
  return ret

# %%
### Find Out How to Preprocess the Data ###
non_numerical_vars: Dict[str, Iterable[Any]] = list_non_numerical_vars(df)
for key, val in non_numerical_vars.items():
  print(f"{key}:", val)
# Out:
# MSZoning: ['RL', 'RM', 'C (all)', 'FV', 'RH']
# Street: ['Pave', 'Grvl']
# Alley: [nan, 'Grvl', 'Pave']
# LotShape: ['Reg', 'IR1', 'IR2', 'IR3']
# LandContour: ['Lvl', 'Bnk', 'Low', 'HLS']
# Utilities: ['AllPub', 'NoSeWa']
# LotConfig: ['Inside', 'FR2', 'Corner', 'CulDSac', 'FR3']
# LandSlope: ['Gtl', 'Mod', 'Sev']
# Neighborhood: ['CollgCr', 'Veenker', 'Crawfor', 'NoRidge', 'Mitchel', 'Somerst', 'NWAmes', 'OldTown', 'BrkSide', 'Sawyer', 'NridgHt', 'NAmes', 'SawyerW', 'IDOTRR', 'MeadowV', 'Edwards', 'Timber', 'Gilbert', 'StoneBr', 'ClearCr', 'NPkVill', 'Blmngtn', 'BrDale', 'SWISU', 'Blueste']
# Condition1: ['Norm', 'Feedr', 'PosN', 'Artery', 'RRAe', 'RRNn', 'RRAn', 'PosA', 'RRNe']
# Condition2: ['Norm', 'Artery', 'RRNn', 'Feedr', 'PosN', 'PosA', 'RRAn', 'RRAe']
# BldgType: ['1Fam', '2fmCon', 'Duplex', 'TwnhsE', 'Twnhs']
# HouseStyle: ['2Story', '1Story', '1.5Fin', '1.5Unf', 'SFoyer', 'SLvl', '2.5Unf', '2.5Fin']
# RoofStyle: ['Gable', 'Hip', 'Gambrel', 'Mansard', 'Flat', 'Shed']
# ...

# %% [markdown]
# ### 2.3. Preprocessing the Dataset

# %%
def preprocess(input: pd.DataFrame, 
               drop_categorical: bool = True, 
               drop_nan_threshold: float = 0.05,
               drop_corr_threshold: float = 0.1) -> pd.DataFrame:
  """Handle variables with non-numerical values."""
  # We do not care about the ID field.
  ret = input.copy()
  ret.drop(columns=["Id"], inplace=True)

  # Some manipulations specific to our dataset.
  # Age is an important derivative variable.
  # We leave the other columns, RF algorithm will choose what's best.
  ret["Age"] = ret["YrSold"] - ret["YearBuilt"]

  corr_matrix = ret.corr()
  corr_coeffs = corr_matrix["SalePrice"].abs().sort_values(ascending=True)

  ret.drop(corr_coeffs[corr_coeffs < drop_corr_threshold].index, axis=1, inplace=True)

  if drop_categorical:
    vars: Iterable[str] = list(list_non_numerical_vars(ret).keys())
    ret.drop(columns=vars, inplace=True)
  else:
    non_numerical_vars = list_non_numerical_vars(ret)
    for key, val in non_numerical_vars.items():
      for idx, item in enumerate(val):
        # One hot encoding
        new_col = f"{key}-{idx}"
        ret[new_col] = 0
        ret.loc[ret[key] == item, new_col] = 1
      ret.drop(columns=[key], inplace=True)

  # If more than a threshold ratio of a column is NaN,
  # we want to drop the column.
  missing_total = ret.isnull().sum().sort_values(ascending=False)
  missing_ratio = (ret.isnull().sum() / ret.isnull().count()).sort_values(ascending=False)
  missing_data = pd.concat([missing_total, missing_ratio], axis=1, keys=["Total", "Ratio"])
  missing_cols = (missing_data[missing_data["Ratio"] > drop_nan_threshold]).index
  ret.drop((missing_data[missing_data["Ratio"] > drop_nan_threshold]).index, axis=1, inplace=True)
  
  # Replace missing values with most common values for that variable.
  remaining_cols = (missing_data[missing_data["Ratio"] <= drop_nan_threshold]).index.tolist()
  for col in remaining_cols:
    ret[col] = ret[col].fillna(ret[col].mode()[0])
  return ret

# %%
### See Preprocessing in Action ###
proc_df = preprocess(df, False)
proc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Columns: 294 entries, LotArea to SaleCondition-5
# dtypes: float64(1), int64(293)
# memory usage: 3.3 MB

# %%
### Find Out Correlation Between Attributes ###
corr_df = proc_df.corr()

# %%
### Determine Most and Least Correlated Attributes with SalePrice ###
corr_coeffs = corr_df["SalePrice"].fillna(0).abs().sort_values(ascending=False)
least_corr, most_corr = corr_coeffs[-5:], corr_coeffs[1:6]

print("Most Correlated")
print(most_corr)
print("Least Correlated")
print(least_corr)
# Out:
# Most Correlated
# OverallQual    0.790982
# GrLivArea      0.708624
# GarageCars     0.640409
# GarageArea     0.623431
# TotalBsmtSF    0.613581
# Name: SalePrice, dtype: float64
# Least Correlated
# BsmtCond-2       0.0
# BsmtQual-3       0.0
# GarageCond-2     0.0
# MiscFeature-0    0.0
# GarageQual-3     0.0
# Name: SalePrice, dtype: float64

# %%
### Graph Most Important Attributes vs. SalePrice ###
for attr in most_corr.index:
  proc_df.plot.scatter(attr, "SalePrice")

# %%
### Split Data Into Test and Train Subsets
SEED = 562
y = proc_df["SalePrice"]
x = proc_df.drop(["SalePrice"], axis=1)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=SEED)

# %% [markdown]
# ## 3. Regression Methods

# %% [markdown]
# ### 3.1. Linear Regression

# %%
### Train the Regressor ###
lin_reg = LinearRegression()

start_time = datetime.now()
print("Start:", start_time)

lin_reg.fit(x_train, y_train)

end_time = datetime.now()
print("End:", end_time)
print("Duration:", end_time - start_time)
# Out:
# Start: 2023-01-04 06:59:49.270930
# End: 2023-01-04 06:59:49.333057
# Duration: 0:00:00.062127

# %%
### Evaluate and Print Metrics ###
lin_y_pred = lin_reg.predict(x_test)
print("Mean Absolute Error:", mean_absolute_error(y_test, lin_y_pred))
print("Mean Squared Error:", mean_squared_error(y_test, lin_y_pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, lin_y_pred)))
# Out:
# Mean Absolute Error: 19678.76540736636
# Mean Squared Error: 2537189883.069324
# Root Mean Squared Error: 50370.52593600075

# %% [markdown]
# ### 3.2. Random Forest Regression

# %%
### Do a Dummy Regression ###
rf_reg = RandomForestRegressor(n_estimators=3,
                               max_depth=2,
                               random_state=SEED)
rf_reg.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=2, n_estimators=3, random_state=562)

# %%
### Display the Forest ###
features = x.columns.values

for estimator in rf_reg.estimators_:
  plt.figure(figsize=(12,6))
  tree.plot_tree(estimator,
                 feature_names=features,
                 fontsize=8,
                 filled=True,
                 rounded=True)
plt.show()

# %%
### Evaluate and Print Metrics ###
rf_y_pred = rf_reg.predict(x_test)
print("Mean Absolute Error:", mean_absolute_error(y_test, rf_y_pred))
print("Mean Squared Error:", mean_squared_error(y_test, rf_y_pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, rf_y_pred)))
# Out:
# Mean Absolute Error: 32391.335190660564
# Mean Squared Error: 1869217735.9222794
# Root Mean Squared Error: 43234.450799359984

# %%
"""
Previous results should be terrible, which is expected as it
is just a demonstration.

Let's see if we can improve upon it using grid search to
optimize parameters.
"""
grid = {
    "n_estimators": [100, 200, 300],
    "max_features": [1.0, "sqrt", "log2"],
    "max_depth": [3, 4, 5, 6, 7],
    "random_state": [SEED],
}

start_time = datetime.now()
print("Start:", start_time)

rf_searcher = GridSearchCV(estimator=RandomForestRegressor(), param_grid=grid)
rf_searcher.fit(x_train, y_train)

end_time = datetime.now()
print("End:", end_time)
print("Duration:", end_time - start_time)
# Out:
# Start: 2023-01-04 06:59:50.064709
# End: 2023-01-04 07:02:06.613385
# Duration: 0:02:16.548676

# %%
### Evaluate and Print Metrics ###
rf_y_pred = rf_searcher.predict(x_test)
print("Mean Absolute Error:", mean_absolute_error(y_test, rf_y_pred))
print("Mean Squared Error:", mean_squared_error(y_test, rf_y_pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, rf_y_pred)))
# Out:
# Mean Absolute Error: 20502.287069788785
# Mean Squared Error: 1064041537.6462921
# Root Mean Squared Error: 32619.64956351144

# %% [markdown]
# ### 3.3. Multilayer Perceptron Regression

# %%
### Do a Dummy Regression ###
mlp_reg = MLPRegressor(random_state=SEED)
mlp_reg.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPRegressor(random_state=562)

# %%
### Evaluate and Print Metrics ###
mlp_y_pred = rf_reg.predict(x_test)
print("Mean Absolute Error:", mean_absolute_error(y_test, mlp_y_pred))
print("Mean Squared Error:", mean_squared_error(y_test, mlp_y_pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, mlp_y_pred)))
# Out:
# Mean Absolute Error: 32391.335190660564
# Mean Squared Error: 1869217735.9222794
# Root Mean Squared Error: 43234.450799359984

# %%
"""
Previous results should be terrible, which is expected as it
is just a demonstration.

Let's see if we can improve upon it using grid search to
optimize parameters.
"""
grid = {
    "activation": ["logistic", "relu"],
    "hidden_layer_sizes": [(100,), (100, 50), (100, 50, 20)],
    "learning_rate": ["constant", "adaptive"],
    "max_iter": [200, 500],
    "random_state": [SEED],
}

start_time = datetime.now()
print("Start:", start_time)

mlp_searcher = GridSearchCV(estimator=MLPRegressor(), param_grid=grid)
mlp_searcher.fit(x_train, y_train)

end_time = datetime.now()
print("End:", end_time)
print("Duration:", end_time - start_time)
# Out:
# Start: 2023-01-04 07:02:08.903085
# /usr/local/lib/python3.8/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...

# %%
### Evaluate and Print Metrics ###
mlp_y_pred = mlp_reg.predict(x_test)
print("Mean Absolute Error:", mean_absolute_error(y_test, mlp_y_pred))
print("Mean Squared Error:", mean_squared_error(y_test, mlp_y_pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, mlp_y_pred)))
# Out:
# Mean Absolute Error: 31055.556238509933
# Mean Squared Error: 2847752458.4349804
# Root Mean Squared Error: 53364.33695301555

# %% [markdown]
# ## 4. Model Evaluation

# %% [markdown]
# ### 4.1. Linear Regression

# %%
### Evaluate and Print Metrics ###
lin_y_pred = lin_reg.predict(x_test)
print("Mean Absolute Error:", mean_absolute_error(y_test, lin_y_pred))
print("Mean Squared Error:", mean_squared_error(y_test, lin_y_pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, lin_y_pred)))
# Out:
# Mean Absolute Error: 19678.76540736636
# Mean Squared Error: 2537189883.069324
# Root Mean Squared Error: 50370.52593600075

# %%
### Compare Prediction with the Real Values ###
plt.figure(figsize=(10,10))
plt.scatter(y_test, lin_y_pred, c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(lin_y_pred), max(y_test))
p2 = min(min(lin_y_pred), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()

# %%
### Graph Most Important Attributes vs. SalePrice ###
curr_df = x_test.copy()
curr_df["SalePriceDiff"] = y_test - lin_y_pred
for attr in most_corr.index:
  curr_df.plot.scatter(attr, "SalePriceDiff")

# %% [markdown]
# ### 4.2. Random Forest Regression

# %%
### Evaluate and Print Metrics ###
rf_y_pred = rf_searcher.predict(x_test)
print("Mean Absolute Error:", mean_absolute_error(y_test, rf_y_pred))
print("Mean Squared Error:", mean_squared_error(y_test, rf_y_pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, rf_y_pred)))
# Out:
# Mean Absolute Error: 20502.287069788785
# Mean Squared Error: 1064041537.6462921
# Root Mean Squared Error: 32619.64956351144

# %%
### Compare Prediction with the Real Values ###
plt.figure(figsize=(10,10))
plt.scatter(y_test, rf_y_pred, c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(rf_y_pred), max(y_test))
p2 = min(min(rf_y_pred), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()

# %%
### Graph Most Important Attributes vs. SalePrice ###
curr_df = x_test.copy()
curr_df["SalePriceDiff"] = y_test - rf_y_pred
for attr in most_corr.index:
  curr_df.plot.scatter(attr, "SalePriceDiff")

# %% [markdown]
# ### 4.3. Multilayer Perceptron Regression

# %%
### Evaluate and Print Metrics ###
mlp_y_pred = mlp_reg.predict(x_test)
print("Mean Absolute Error:", mean_absolute_error(y_test, mlp_y_pred))
print("Mean Squared Error:", mean_squared_error(y_test, mlp_y_pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, mlp_y_pred)))
# Out:
# Mean Absolute Error: 31055.556238509933
# Mean Squared Error: 2847752458.4349804
# Root Mean Squared Error: 53364.33695301555

# %%
### Compare Prediction with the Real Values ###
plt.figure(figsize=(10,10))
plt.scatter(y_test, mlp_y_pred, c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(mlp_y_pred), max(y_test))
p2 = min(min(mlp_y_pred), min(y_test))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('True Values', fontsize=15)
plt.ylabel('Predictions', fontsize=15)
plt.axis('equal')
plt.show()

# %%
### Graph Most Important Attributes vs. SalePrice ###
curr_df = x_test.copy()
curr_df["SalePriceDiff"] = y_test - mlp_y_pred
for attr in most_corr.index:
  curr_df.plot.scatter(attr, "SalePriceDiff")

# %% [markdown]
# ## 5. Model Comparison

# %%
### Compare Prediction with the Real Values ###
plt.figure(figsize=(10,10))
plt.scatter(lin_y_pred, rf_y_pred, c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(rf_y_pred), max(lin_y_pred))
p2 = min(min(rf_y_pred), min(lin_y_pred))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('LR Predictions', fontsize=15)
plt.ylabel('RF Predictions', fontsize=15)
plt.axis('equal')
plt.show()

# %%
### Compare Prediction with the Real Values ###
plt.figure(figsize=(10,10))
plt.scatter(lin_y_pred, mlp_y_pred, c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(mlp_y_pred), max(lin_y_pred))
p2 = min(min(mlp_y_pred), min(lin_y_pred))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('LR Predictions', fontsize=15)
plt.ylabel('MLP Predictions', fontsize=15)
plt.axis('equal')
plt.show()

# %%
### Compare Prediction with the Real Values ###
plt.figure(figsize=(10,10))
plt.scatter(rf_y_pred, mlp_y_pred, c='crimson')
plt.yscale('log')
plt.xscale('log')

p1 = max(max(mlp_y_pred), max(rf_y_pred))
p2 = min(min(mlp_y_pred), min(rf_y_pred))
plt.plot([p1, p2], [p1, p2], 'b-')
plt.xlabel('RF Predictions', fontsize=15)
plt.ylabel('MLP Predictions', fontsize=15)
plt.axis('equal')
plt.show()

# %%
### Box Plots for Cross Similarity ###
curr_df = x_test.copy()
curr_df["SalePrice"] = y_test
curr_df["LRPrediction"] = lin_y_pred
curr_df["RFPrediction"] = rf_y_pred
curr_df["MLPPrediction"] = mlp_y_pred
curr_df.boxplot(column=["SalePrice", "LRPrediction", "RFPrediction", "MLPPrediction"], figsize=(10,10))
